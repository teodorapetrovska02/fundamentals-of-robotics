# %%
import sympy as sp
import script as rt

# %%
## Задача 1

# %%
theta1, theta2, theta3= sp.symbols('theta1, theta2, theta3') 
robot = rt.SerialLinkRobot()
robot.add_revolute_joint(0, 2, 0, 0) #L1 ke e mrtov zglob odnosno kruta pracka
robot.add_revolute_joint(theta1, 1.5, 0, -sp.pi/2) #L2
robot.add_revolute_joint(theta2, 0, 1, 0) #L3
robot.add_revolute_joint(theta3, 0, 0.5, 0)#L4
# koristime skaliranje na dolzinite 1:2
robot.interact()

# %%
robot.get_dh_matrix()
# Out:
# Matrix([
# [cos(theta1)*cos(theta2 + theta3), -sin(theta2 + theta3)*cos(theta1), -sin(theta1), (1.0*cos(theta2) + 0.5*cos(theta2 + theta3))*cos(theta1)],
# [sin(theta1)*cos(theta2 + theta3), -sin(theta1)*sin(theta2 + theta3),  cos(theta1), (1.0*cos(theta2) + 0.5*cos(theta2 + theta3))*sin(theta1)],
# [           -sin(theta2 + theta3),             -cos(theta2 + theta3),            0,        -1.0*sin(theta2) - 0.5*sin(theta2 + theta3) + 3.5],
# [                               0,                                 0,            0,                                                        1]])
